# %% [markdown]
# # Spark Train Logistic Regression

# %% [markdown]
# Train Logistic Regression classifier with Apache SparkML

# %%
import warnings
warnings.filterwarnings('ignore')
from pyspark import SparkContext, SparkConf, SQLContext
import os
from pyspark.ml.classification import LogisticRegression
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark2pmml import PMMLBuilder
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import MinMaxScaler
import logging
logging.disable(level = 'CRITICAL')
import shutil
import site
import sys
import wget
import re

# %%
data_parquet = os.environ.get('data_parquet',
                              'data.parquet')  # input file name (parquet)
master = os.environ.get('master',
                        "local[*]")  # URL to Spark master
model_target = os.environ.get('model_target',
                              "model.xml")  # model output file name
data_dir = os.environ.get('data_dir',
                          'data/')  # temporary directory for data
input_columns = os.environ.get('input_columns',
                               '["x", "y", "z"]')  # input columns to consider

# %%
parameters = list(
    map(lambda s: re.sub('$', '"', s),
        map(
            lambda s: s.replace('=', '="'),
            filter(
                lambda s: s.find('=') > -1 and bool(re.match(r'[A-Za-z0-9_]*=[.\/A-Za-z0-9]*', s)),
                sys.argv
            )
    )))

for parameter in parameters:
    logging.warning('Parameter: ' + parameter)
    exec(parameter)

# %%
conf = SparkConf().setMaster(master)
#if sys.version[0:3] == '3.6' or sys.version[0:3] == '3.7':
conf.set("spark.jars", "Private/main/pmml-sparkml-example-executable-2.4.0.jar")

sc = SparkContext.getOrCreate(conf)
sqlContext = SQLContext(sc)
spark = sqlContext.sparkSession
# Out:
# 23/07/10 12:01:20 WARN Utils: Your hostname, davis-VirtualBox resolves to a loopback address: 127.0.1.1; using 10.0.2.15 instead (on interface enp0s3)
# 23/07/10 12:01:20 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 23/07/10 12:01:21 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/07/10 12:01:21 WARN DependencyUtils: Local jar /home/davis/.local/lib/python3.10/site-packages/pyspark/jars/japmml-sparkml-example-executable-2.4.0.jar does not exist, skipping.
# 23/07/10 12:01:22 INFO SparkContext: Running Spark version 3.4.1
# 23/07/10 12:01:22 INFO ResourceUtils: ==============================================================
# 23/07/10 12:01:22 INFO ResourceUtils: No custom resources configured for spark.driver.
# 23/07/10 12:01:22 INFO ResourceUtils: ==============================================================
# 23/07/10 12:01:22 INFO SparkContext: Submitted application: pyspark-shell
# 23/07/10 12:01:22 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
# 23/07/10 12:01:22 INFO ResourceProfile: Limiting resource is cpu
# 23/07/10 12:01:22 INFO ResourceProfileManager: Added ResourceProfile id: 0
# 23/07/10 12:01:22 INFO SecurityManager: Changing view acls to: davis
# 23/07/10 12:01:22 INFO SecurityManager: Changing modify acls to: davis
# 23/07/10 12:01:22 INFO SecurityManager: Changing view acls groups to:
# 23/07/10 12:01:22 INFO SecurityManager: Changing modify acls groups to:
# 23/07/10 12:01:22 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: davis; groups with view permissions: EMPTY; users with modify permissions: davis; groups with modify permissions: EMPTY
# 23/07/10 12:01:23 INFO Utils: Successfully started service 'sparkDriver' on port 37877.
# 23/07/10 12:01:23 INFO SparkEnv: Registering MapOutputTracker
# 23/07/10 12:01:23 INFO SparkEnv: Registering BlockManagerMaster
# 23/07/10 12:01:23 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 23/07/10 12:01:23 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 23/07/10 12:01:23 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 23/07/10 12:01:23 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-af31b58d-87db-4a2d-8e9f-f3050763fc3f
# 23/07/10 12:01:23 INFO MemoryStore: MemoryStore started with capacity 434.4 MiB
# 23/07/10 12:01:23 INFO SparkEnv: Registering OutputCommitCoordinator
# 23/07/10 12:01:23 INFO JettyUtils: Start Jetty 0.0.0.0:4040 for SparkUI
# 23/07/10 12:01:24 INFO Utils: Successfully started service 'SparkUI' on port 4040.
# 23/07/10 12:01:24 ERROR SparkContext: Failed to add Private/main/pmml-sparkml-example-executable-2.4.0.jar to Spark environment
# java.io.FileNotFoundException: Jar /home/davis/Private/main/Private/main/pmml-sparkml-example-executable-2.4.0.jar not found
# 	at org.apache.spark.SparkContext.addLocalJarFile$1(SparkContext.scala:1968)
# 	at org.apache.spark.SparkContext.addJar(SparkContext.scala:2023)
# 	at org.apache.spark.SparkContext.$anonfun$new$12(SparkContext.scala:507)
# 	at org.apache.spark.SparkContext.$anonfun$new$12$adapted(SparkContext.scala:507)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.SparkContext.<init>(SparkContext.scala:507)
# 	at org.apache.spark.api.java.JavaSparkContext.<init>(JavaSparkContext.scala:58)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
# 	at java.base/jdk.internal.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# 	at java.base/java.lang.reflect.Constructor.newInstance(Constructor.java:490)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)
# 	at py4j.Gateway.invoke(Gateway.java:238)
# 	at py4j.commands.ConstructorCommand.invokeConstructor(ConstructorCommand.java:80)
# 	at py4j.commands.ConstructorCommand.execute(ConstructorCommand.java:69)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 23/07/10 12:01:24 INFO Executor: Starting executor ID driver on host 10.0.2.15
# 23/07/10 12:01:24 INFO Executor: Starting executor with user classpath (userClassPathFirst = false): ''
# 23/07/10 12:01:24 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 46735.
# 23/07/10 12:01:24 INFO NettyBlockTransferService: Server created on 10.0.2.15:46735
# 23/07/10 12:01:24 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 23/07/10 12:01:24 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None)
# 23/07/10 12:01:24 INFO BlockManagerMasterEndpoint: Registering block manager 10.0.2.15:46735 with 434.4 MiB RAM, BlockManagerId(driver, 10.0.2.15, 46735, None)
# 23/07/10 12:01:24 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None)
# 23/07/10 12:01:24 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 10.0.2.15, 46735, None)

# %%
df = spark.read.parquet(data_dir + data_parquet)
# Out:
# 23/07/10 12:01:24 INFO SharedState: Setting hive.metastore.warehouse.dir ('null') to the value of spark.sql.warehouse.dir.
# 23/07/10 12:01:25 INFO SharedState: Warehouse path is 'file:/home/davis/Private/main/spark-warehouse'.
# 23/07/10 12:01:27 INFO InMemoryFileIndex: It took 104 ms to list leaf files for 1 paths.
# 23/07/10 12:01:28 INFO SparkContext: Starting job: parquet at NativeMethodAccessorImpl.java:0
# 23/07/10 12:01:28 INFO DAGScheduler: Got job 0 (parquet at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 23/07/10 12:01:28 INFO DAGScheduler: Final stage: ResultStage 0 (parquet at NativeMethodAccessorImpl.java:0)
# 23/07/10 12:01:28 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:01:28 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:01:28 INFO DAGScheduler: Submitting ResultStage 0 (MapPartitionsRDD[1] at parquet at NativeMethodAccessorImpl.java:0), which has no missing parents
# 23/07/10 12:01:28 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 103.5 KiB, free 434.3 MiB)
# 23/07/10 12:01:28 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 37.4 KiB, free 434.3 MiB)
# 23/07/10 12:01:28 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on 10.0.2.15:46735 (size: 37.4 KiB, free: 434.4 MiB)
# 23/07/10 12:01:28 INFO SparkContext: Created broadcast 0 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:01:28 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 0 (MapPartitionsRDD[1] at parquet at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:01:28 INFO TaskSchedulerImpl: Adding task set 0.0 with 1 tasks resource profile 0
# 23/07/10 12:01:29 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7573 bytes)
# 23/07/10 12:01:29 INFO Executor: Running task 0.0 in stage 0.0 (TID 0) + 0) / 1]
# 23/07/10 12:01:29 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1951 bytes result sent to driver
# 23/07/10 12:01:29 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 733 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:01:29 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 23/07/10 12:01:29 INFO DAGScheduler: ResultStage 0 (parquet at NativeMethodAccessorImpl.java:0) finished in 1.363 s
# 23/07/10 12:01:29 INFO DAGScheduler: Job 0 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:01:29 INFO TaskSchedulerImpl: Killing all running tasks in stage 0: Stage finished
# 23/07/10 12:01:29 INFO DAGScheduler: Job 0 finished: parquet at NativeMethodAccessorImpl.java:0, took 1.489738 s
# 23/07/10 12:01:30 INFO BlockManagerInfo: Removed broadcast_0_piece0 on 10.0.2.15:46735 in memory (size: 37.4 KiB, free: 434.4 MiB)

# %%
# register a corresponding query table
df.createOrReplaceTempView('df')

# %%
from pyspark.sql.types import DoubleType
df = df.withColumn("x", df.x.cast(DoubleType()))
df = df.withColumn("y", df.y.cast(DoubleType()))
df = df.withColumn("z", df.z.cast(DoubleType()))

# %%
splits = df.randomSplit([0.8, 0.2])
df_train = splits[0]
df_test = splits[1]

# %%
indexer = StringIndexer(inputCol="class", outputCol="label")

vectorAssembler = VectorAssembler(inputCols=eval(input_columns),
                                  outputCol="features")

normalizer = MinMaxScaler(inputCol="features", outputCol="features_norm")

# %%
#lr = LogisticRegression(maxIter=10, regParam=0.3, elasticNetParam=0.8)
lr = LogisticRegression(maxIter=1000, regParam=0.05, elasticNetParam=0.6)

# %%
pipeline = Pipeline(stages=[indexer, vectorAssembler, normalizer, lr])

# %%
model = pipeline.fit(df_train)
# Out:
# 23/07/10 12:13:09 INFO FileSourceStrategy: Pushed Filters:
# 23/07/10 12:13:09 INFO FileSourceStrategy: Post-Scan Filters:
# 23/07/10 12:13:09 INFO MemoryStore: Block broadcast_407 stored as values in memory (estimated size 201.8 KiB, free 432.5 MiB)
# 23/07/10 12:13:09 INFO MemoryStore: Block broadcast_407_piece0 stored as bytes in memory (estimated size 35.1 KiB, free 432.4 MiB)
# 23/07/10 12:13:09 INFO BlockManagerInfo: Added broadcast_407_piece0 in memory on 10.0.2.15:46735 (size: 35.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:09 INFO SparkContext: Created broadcast 407 from collect at StringIndexer.scala:204
# 23/07/10 12:13:09 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 23/07/10 12:13:09 INFO DAGScheduler: Registering RDD 497 (collect at StringIndexer.scala:204) as input to shuffle 18
# 23/07/10 12:13:09 INFO DAGScheduler: Got map stage job 195 (collect at StringIndexer.scala:204) with 1 output partitions
# 23/07/10 12:13:09 INFO DAGScheduler: Final stage: ShuffleMapStage 213 (collect at StringIndexer.scala:204)
# 23/07/10 12:13:09 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:09 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:09 INFO DAGScheduler: Submitting ShuffleMapStage 213 (MapPartitionsRDD[497] at collect at StringIndexer.scala:204), which has no missing parents
# 23/07/10 12:13:09 INFO MemoryStore: Block broadcast_408 stored as values in memory (estimated size 40.0 KiB, free 432.4 MiB)
# 23/07/10 12:13:09 INFO MemoryStore: Block broadcast_408_piece0 stored as bytes in memory (estimated size 17.6 KiB, free 432.4 MiB)
# 23/07/10 12:13:09 INFO BlockManagerInfo: Added broadcast_408_piece0 in memory on 10.0.2.15:46735 (size: 17.6 KiB, free: 434.1 MiB)
# 23/07/10 12:13:09 INFO SparkContext: Created broadcast 408 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:09 INFO DAGScheduler: Submitting 1 missing tasks from ShuffleMapStage 213 (MapPartitionsRDD[497] at collect at StringIndexer.scala:204) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:09 INFO TaskSchedulerImpl: Adding task set 213.0 with 1 tasks resource profile 0
# 23/07/10 12:13:09 INFO TaskSetManager: Starting task 0.0 in stage 213.0 (TID 201) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7986 bytes)
# 23/07/10 12:13:09 INFO Executor: Running task 0.0 in stage 213.0 (TID 201)
# 23/07/10 12:13:09 INFO FileScanRDD: Reading File path: file:///home/davis/Private/main/data/data.parquet/part-00000-f0dd6904-04fe-4ee6-9a17-0c5e52be30ef-c000.snappy.parquet, range: 0-969453, partition values: [empty row]
# 23/07/10 12:13:09 INFO BlockManagerInfo: Removed broadcast_405_piece0 on 10.0.2.15:46735 in memory (size: 34.6 KiB, free: 434.1 MiB)
# 23/07/10 12:13:09 INFO BlockManagerInfo: Removed broadcast_406_piece0 on 10.0.2.15:46735 in memory (size: 2.8 KiB, free: 434.1 MiB)
# 23/07/10 12:13:09 INFO BlockManagerInfo: Removed broadcast_404_piece0 on 10.0.2.15:46735 in memory (size: 35.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:10 INFO Executor: Finished task 0.0 in stage 213.0 (TID 201). 2861 bytes result sent to driver
# 23/07/10 12:13:10 INFO TaskSetManager: Finished task 0.0 in stage 213.0 (TID 201) in 1041 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:10 INFO TaskSchedulerImpl: Removed TaskSet 213.0, whose tasks have all completed, from pool
# 23/07/10 12:13:10 INFO DAGScheduler: ShuffleMapStage 213 (collect at StringIndexer.scala:204) finished in 1.049 s
# 23/07/10 12:13:10 INFO DAGScheduler: looking for newly runnable stages
# 23/07/10 12:13:10 INFO DAGScheduler: running: Set()
# 23/07/10 12:13:10 INFO DAGScheduler: waiting: Set()
# 23/07/10 12:13:10 INFO DAGScheduler: failed: Set()
# 23/07/10 12:13:10 INFO SparkContext: Starting job: collect at StringIndexer.scala:204
# 23/07/10 12:13:10 INFO DAGScheduler: Got job 196 (collect at StringIndexer.scala:204) with 1 output partitions
# 23/07/10 12:13:10 INFO DAGScheduler: Final stage: ResultStage 215 (collect at StringIndexer.scala:204)
# 23/07/10 12:13:10 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 214)
# 23/07/10 12:13:10 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:10 INFO DAGScheduler: Submitting ResultStage 215 (MapPartitionsRDD[500] at collect at StringIndexer.scala:204), which has no missing parents
# 23/07/10 12:13:10 INFO MemoryStore: Block broadcast_409 stored as values in memory (estimated size 35.0 KiB, free 432.7 MiB)
# 23/07/10 12:13:10 INFO MemoryStore: Block broadcast_409_piece0 stored as bytes in memory (estimated size 16.4 KiB, free 432.7 MiB)
# 23/07/10 12:13:10 INFO BlockManagerInfo: Added broadcast_409_piece0 in memory on 10.0.2.15:46735 (size: 16.4 KiB, free: 434.1 MiB)
# 23/07/10 12:13:10 INFO SparkContext: Created broadcast 409 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:10 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 215 (MapPartitionsRDD[500] at collect at StringIndexer.scala:204) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:10 INFO TaskSchedulerImpl: Adding task set 215.0 with 1 tasks resource profile 0
# 23/07/10 12:13:10 INFO TaskSetManager: Starting task 0.0 in stage 215.0 (TID 202) (10.0.2.15, executor driver, partition 0, NODE_LOCAL, 7363 bytes)
# 23/07/10 12:13:10 INFO Executor: Running task 0.0 in stage 215.0 (TID 202)
# 23/07/10 12:13:10 INFO ShuffleBlockFetcherIterator: Getting 1 (593.0 B) non-empty blocks including 1 (593.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 23/07/10 12:13:10 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 0 ms
# 23/07/10 12:13:10 INFO Executor: Finished task 0.0 in stage 215.0 (TID 202). 5678 bytes result sent to driver
# 23/07/10 12:13:10 INFO TaskSetManager: Finished task 0.0 in stage 215.0 (TID 202) in 19 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:10 INFO TaskSchedulerImpl: Removed TaskSet 215.0, whose tasks have all completed, from pool
# 23/07/10 12:13:10 INFO DAGScheduler: ResultStage 215 (collect at StringIndexer.scala:204) finished in 0.023 s
# 23/07/10 12:13:10 INFO DAGScheduler: Job 196 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:10 INFO TaskSchedulerImpl: Killing all running tasks in stage 215: Stage finished
# 23/07/10 12:13:10 INFO DAGScheduler: Job 196 finished: collect at StringIndexer.scala:204, took 0.024366 s
# 23/07/10 12:13:10 INFO FileSourceStrategy: Pushed Filters:
# 23/07/10 12:13:10 INFO FileSourceStrategy: Post-Scan Filters:
# 23/07/10 12:13:10 INFO MemoryStore: Block broadcast_410 stored as values in memory (estimated size 201.8 KiB, free 432.5 MiB)
# 23/07/10 12:13:10 INFO MemoryStore: Block broadcast_410_piece0 stored as bytes in memory (estimated size 35.1 KiB, free 432.4 MiB)
# 23/07/10 12:13:10 INFO BlockManagerInfo: Added broadcast_410_piece0 in memory on 10.0.2.15:46735 (size: 35.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:10 INFO SparkContext: Created broadcast 410 from first at MinMaxScaler.scala:120
# 23/07/10 12:13:10 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 23/07/10 12:13:10 INFO DAGScheduler: Registering RDD 505 (first at MinMaxScaler.scala:120) as input to shuffle 19
# 23/07/10 12:13:10 INFO DAGScheduler: Got map stage job 197 (first at MinMaxScaler.scala:120) with 1 output partitions
# 23/07/10 12:13:10 INFO DAGScheduler: Final stage: ShuffleMapStage 216 (first at MinMaxScaler.scala:120)
# 23/07/10 12:13:10 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:10 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:10 INFO DAGScheduler: Submitting ShuffleMapStage 216 (MapPartitionsRDD[505] at first at MinMaxScaler.scala:120), which has no missing parents
# 23/07/10 12:13:10 INFO MemoryStore: Block broadcast_411 stored as values in memory (estimated size 51.9 KiB, free 432.4 MiB)
# 23/07/10 12:13:10 INFO MemoryStore: Block broadcast_411_piece0 stored as bytes in memory (estimated size 22.1 KiB, free 432.4 MiB)
# 23/07/10 12:13:10 INFO BlockManagerInfo: Added broadcast_411_piece0 in memory on 10.0.2.15:46735 (size: 22.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:10 INFO SparkContext: Created broadcast 411 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:10 INFO DAGScheduler: Submitting 1 missing tasks from ShuffleMapStage 216 (MapPartitionsRDD[505] at first at MinMaxScaler.scala:120) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:10 INFO TaskSchedulerImpl: Adding task set 216.0 with 1 tasks resource profile 0
# 23/07/10 12:13:10 INFO TaskSetManager: Starting task 0.0 in stage 216.0 (TID 203) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7986 bytes)
# 23/07/10 12:13:10 INFO Executor: Running task 0.0 in stage 216.0 (TID 203)
# 23/07/10 12:13:10 INFO FileScanRDD: Reading File path: file:///home/davis/Private/main/data/data.parquet/part-00000-f0dd6904-04fe-4ee6-9a17-0c5e52be30ef-c000.snappy.parquet, range: 0-969453, partition values: [empty row]
# 23/07/10 12:13:10 INFO BlockManagerInfo: Removed broadcast_407_piece0 on 10.0.2.15:46735 in memory (size: 35.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:10 INFO BlockManagerInfo: Removed broadcast_409_piece0 on 10.0.2.15:46735 in memory (size: 16.4 KiB, free: 434.1 MiB)
# 23/07/10 12:13:10 INFO BlockManagerInfo: Removed broadcast_408_piece0 on 10.0.2.15:46735 in memory (size: 17.6 KiB, free: 434.1 MiB)
# 23/07/10 12:13:11 INFO Executor: Finished task 0.0 in stage 216.0 (TID 203). 2861 bytes result sent to driver
# 23/07/10 12:13:11 INFO TaskSetManager: Finished task 0.0 in stage 216.0 (TID 203) in 955 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:11 INFO TaskSchedulerImpl: Removed TaskSet 216.0, whose tasks have all completed, from pool
# 23/07/10 12:13:11 INFO DAGScheduler: ShuffleMapStage 216 (first at MinMaxScaler.scala:120) finished in 0.963 s
# 23/07/10 12:13:11 INFO DAGScheduler: looking for newly runnable stages
# 23/07/10 12:13:11 INFO DAGScheduler: running: Set()
# 23/07/10 12:13:11 INFO DAGScheduler: waiting: Set()
# 23/07/10 12:13:11 INFO DAGScheduler: failed: Set()
# 23/07/10 12:13:11 INFO SparkContext: Starting job: first at MinMaxScaler.scala:120
# 23/07/10 12:13:11 INFO DAGScheduler: Got job 198 (first at MinMaxScaler.scala:120) with 1 output partitions
# 23/07/10 12:13:11 INFO DAGScheduler: Final stage: ResultStage 218 (first at MinMaxScaler.scala:120)
# 23/07/10 12:13:11 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 217)
# 23/07/10 12:13:11 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:11 INFO DAGScheduler: Submitting ResultStage 218 (MapPartitionsRDD[509] at first at MinMaxScaler.scala:120), which has no missing parents
# 23/07/10 12:13:11 INFO MemoryStore: Block broadcast_412 stored as values in memory (estimated size 49.7 KiB, free 432.7 MiB)
# 23/07/10 12:13:11 INFO MemoryStore: Block broadcast_412_piece0 stored as bytes in memory (estimated size 21.9 KiB, free 432.6 MiB)
# 23/07/10 12:13:11 INFO BlockManagerInfo: Added broadcast_412_piece0 in memory on 10.0.2.15:46735 (size: 21.9 KiB, free: 434.1 MiB)
# 23/07/10 12:13:11 INFO SparkContext: Created broadcast 412 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:11 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 218 (MapPartitionsRDD[509] at first at MinMaxScaler.scala:120) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:11 INFO TaskSchedulerImpl: Adding task set 218.0 with 1 tasks resource profile 0
# 23/07/10 12:13:11 INFO TaskSetManager: Starting task 0.0 in stage 218.0 (TID 204) (10.0.2.15, executor driver, partition 0, NODE_LOCAL, 7363 bytes)
# 23/07/10 12:13:11 INFO Executor: Running task 0.0 in stage 218.0 (TID 204)
# 23/07/10 12:13:11 INFO ShuffleBlockFetcherIterator: Getting 1 (717.0 B) non-empty blocks including 1 (717.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 23/07/10 12:13:11 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 0 ms
# 23/07/10 12:13:11 INFO Executor: Finished task 0.0 in stage 218.0 (TID 204). 5304 bytes result sent to driver
# 23/07/10 12:13:11 INFO TaskSetManager: Finished task 0.0 in stage 218.0 (TID 204) in 10 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:11 INFO TaskSchedulerImpl: Removed TaskSet 218.0, whose tasks have all completed, from pool
# 23/07/10 12:13:11 INFO DAGScheduler: ResultStage 218 (first at MinMaxScaler.scala:120) finished in 0.015 s
# 23/07/10 12:13:11 INFO DAGScheduler: Job 198 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:11 INFO TaskSchedulerImpl: Killing all running tasks in stage 218: Stage finished
# 23/07/10 12:13:11 INFO DAGScheduler: Job 198 finished: first at MinMaxScaler.scala:120, took 0.016011 s
# 23/07/10 12:13:11 INFO Instrumentation: [38a8ba36] Stage class: LogisticRegression
# 23/07/10 12:13:11 INFO Instrumentation: [38a8ba36] Stage uid: LogisticRegression_ec45d06865d8
# 23/07/10 12:13:11 INFO FileSourceStrategy: Pushed Filters:
# 23/07/10 12:13:11 INFO FileSourceStrategy: Post-Scan Filters:
# 23/07/10 12:13:11 INFO MemoryStore: Block broadcast_413 stored as values in memory (estimated size 201.8 KiB, free 432.4 MiB)
# 23/07/10 12:13:11 INFO MemoryStore: Block broadcast_413_piece0 stored as bytes in memory (estimated size 35.1 KiB, free 432.4 MiB)
# 23/07/10 12:13:11 INFO BlockManagerInfo: Added broadcast_413_piece0 in memory on 10.0.2.15:46735 (size: 35.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:11 INFO SparkContext: Created broadcast 413 from rdd at Instrumentation.scala:62
# 23/07/10 12:13:11 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 23/07/10 12:13:11 INFO Instrumentation: [38a8ba36] training: numPartitions=1 storageLevel=StorageLevel(1 replicas)
# 23/07/10 12:13:11 INFO Instrumentation: [38a8ba36] {"regParam":0.05,"elasticNetParam":0.6,"maxIter":1000}
# 23/07/10 12:13:11 INFO FileSourceStrategy: Pushed Filters:
# 23/07/10 12:13:11 INFO FileSourceStrategy: Post-Scan Filters:
# 23/07/10 12:13:11 INFO MemoryStore: Block broadcast_414 stored as values in memory (estimated size 201.8 KiB, free 432.2 MiB)
# 23/07/10 12:13:11 INFO MemoryStore: Block broadcast_414_piece0 stored as bytes in memory (estimated size 35.1 KiB, free 432.2 MiB)
# 23/07/10 12:13:11 INFO BlockManagerInfo: Added broadcast_414_piece0 in memory on 10.0.2.15:46735 (size: 35.1 KiB, free: 434.0 MiB)
# 23/07/10 12:13:11 INFO SparkContext: Created broadcast 414 from rdd at LogisticRegression.scala:512
# 23/07/10 12:13:11 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 23/07/10 12:13:11 INFO SparkContext: Starting job: treeAggregate at Summarizer.scala:233
# 23/07/10 12:13:11 INFO DAGScheduler: Got job 199 (treeAggregate at Summarizer.scala:233) with 1 output partitions
# 23/07/10 12:13:11 INFO DAGScheduler: Final stage: ResultStage 219 (treeAggregate at Summarizer.scala:233)
# 23/07/10 12:13:11 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:11 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:11 INFO DAGScheduler: Submitting ResultStage 219 (MapPartitionsRDD[523] at treeAggregate at Summarizer.scala:233), which has no missing parents
# 23/07/10 12:13:11 INFO MemoryStore: Block broadcast_415 stored as values in memory (estimated size 83.1 KiB, free 432.1 MiB)
# 23/07/10 12:13:11 INFO MemoryStore: Block broadcast_415_piece0 stored as bytes in memory (estimated size 33.1 KiB, free 432.1 MiB)
# 23/07/10 12:13:11 INFO BlockManagerInfo: Added broadcast_415_piece0 in memory on 10.0.2.15:46735 (size: 33.1 KiB, free: 434.0 MiB)
# 23/07/10 12:13:11 INFO SparkContext: Created broadcast 415 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:11 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 219 (MapPartitionsRDD[523] at treeAggregate at Summarizer.scala:233) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:11 INFO TaskSchedulerImpl: Adding task set 219.0 with 1 tasks resource profile 0
# 23/07/10 12:13:11 INFO TaskSetManager: Starting task 0.0 in stage 219.0 (TID 205) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:11 INFO Executor: Running task 0.0 in stage 219.0 (TID 205)
# 23/07/10 12:13:11 INFO FileScanRDD: Reading File path: file:///home/davis/Private/main/data/data.parquet/part-00000-f0dd6904-04fe-4ee6-9a17-0c5e52be30ef-c000.snappy.parquet, range: 0-969453, partition values: [empty row]
# 23/07/10 12:13:12 INFO BlockManagerInfo: Removed broadcast_412_piece0 on 10.0.2.15:46735 in memory (size: 21.9 KiB, free: 434.0 MiB)
# 23/07/10 12:13:12 INFO BlockManagerInfo: Removed broadcast_410_piece0 on 10.0.2.15:46735 in memory (size: 35.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:12 INFO BlockManagerInfo: Removed broadcast_411_piece0 on 10.0.2.15:46735 in memory (size: 22.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:13 INFO Executor: Finished task 0.0 in stage 219.0 (TID 205). 3916 bytes result sent to driver
# 23/07/10 12:13:13 INFO TaskSetManager: Finished task 0.0 in stage 219.0 (TID 205) in 1404 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:13 INFO TaskSchedulerImpl: Removed TaskSet 219.0, whose tasks have all completed, from pool
# 23/07/10 12:13:13 INFO DAGScheduler: ResultStage 219 (treeAggregate at Summarizer.scala:233) finished in 1.414 s
# 23/07/10 12:13:13 INFO DAGScheduler: Job 199 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:13 INFO TaskSchedulerImpl: Killing all running tasks in stage 219: Stage finished
# 23/07/10 12:13:13 INFO DAGScheduler: Job 199 finished: treeAggregate at Summarizer.scala:233, took 1.416179 s
# 23/07/10 12:13:13 INFO Instrumentation: [38a8ba36] {"numClasses":14}
# 23/07/10 12:13:13 INFO Instrumentation: [38a8ba36] {"numFeatures":3}
# 23/07/10 12:13:13 INFO Instrumentation: [38a8ba36] {"numExamples":356907}
# 23/07/10 12:13:13 INFO Instrumentation: [38a8ba36] {"lowestLabelWeight":"5327.0"}
# 23/07/10 12:13:13 INFO Instrumentation: [38a8ba36] {"highestLabelWeight":"73568.0"}
# 23/07/10 12:13:13 INFO Instrumentation: [38a8ba36] {"sumOfWeights":356907.0}
# 23/07/10 12:13:13 INFO Instrumentation: [38a8ba36] {"actualBlockSizeInMB":"1.0"}
# 23/07/10 12:13:13 INFO MemoryStore: Block broadcast_416 stored as values in memory (estimated size 64.0 B, free 432.4 MiB)
# 23/07/10 12:13:13 INFO MemoryStore: Block broadcast_416_piece0 stored as bytes in memory (estimated size 93.0 B, free 432.4 MiB)
# 23/07/10 12:13:13 INFO BlockManagerInfo: Added broadcast_416_piece0 in memory on 10.0.2.15:46735 (size: 93.0 B, free: 434.1 MiB)
# 23/07/10 12:13:13 INFO SparkContext: Created broadcast 416 from broadcast at LogisticRegression.scala:964
# 23/07/10 12:13:13 INFO MemoryStore: Block broadcast_417 stored as values in memory (estimated size 64.0 B, free 432.4 MiB)
# 23/07/10 12:13:13 INFO MemoryStore: Block broadcast_417_piece0 stored as bytes in memory (estimated size 93.0 B, free 432.4 MiB)
# 23/07/10 12:13:13 INFO BlockManagerInfo: Added broadcast_417_piece0 in memory on 10.0.2.15:46735 (size: 93.0 B, free: 434.1 MiB)
# 23/07/10 12:13:13 INFO SparkContext: Created broadcast 417 from broadcast at LogisticRegression.scala:965
# 23/07/10 12:13:13 INFO MemoryStore: Block broadcast_418 stored as values in memory (estimated size 504.0 B, free 432.4 MiB)
# 23/07/10 12:13:13 INFO MemoryStore: Block broadcast_418_piece0 stored as bytes in memory (estimated size 260.0 B, free 432.4 MiB)
# 23/07/10 12:13:13 INFO BlockManagerInfo: Added broadcast_418_piece0 in memory on 10.0.2.15:46735 (size: 260.0 B, free: 434.1 MiB)
# 23/07/10 12:13:13 INFO SparkContext: Created broadcast 418 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:13 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:13 INFO DAGScheduler: Got job 200 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:13 INFO DAGScheduler: Final stage: ResultStage 220 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:13 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:13 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:13 INFO DAGScheduler: Submitting ResultStage 220 (MapPartitionsRDD[526] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:13 INFO MemoryStore: Block broadcast_419 stored as values in memory (estimated size 83.8 KiB, free 432.4 MiB)
# 23/07/10 12:13:13 INFO MemoryStore: Block broadcast_419_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 432.3 MiB)
# 23/07/10 12:13:13 INFO BlockManagerInfo: Added broadcast_419_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 434.1 MiB)
# 23/07/10 12:13:13 INFO SparkContext: Created broadcast 419 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:13 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 220 (MapPartitionsRDD[526] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:13 INFO TaskSchedulerImpl: Adding task set 220.0 with 1 tasks resource profile 0
# 23/07/10 12:13:13 INFO TaskSetManager: Starting task 0.0 in stage 220.0 (TID 206) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:13 INFO Executor: Running task 0.0 in stage 220.0 (TID 206)
# 23/07/10 12:13:13 INFO FileScanRDD: Reading File path: file:///home/davis/Private/main/data/data.parquet/part-00000-f0dd6904-04fe-4ee6-9a17-0c5e52be30ef-c000.snappy.parquet, range: 0-969453, partition values: [empty row]
# 23/07/10 12:13:13 INFO BlockManagerInfo: Removed broadcast_415_piece0 on 10.0.2.15:46735 in memory (size: 33.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:14 INFO MemoryStore: Block rdd_525_0 stored as values in memory (estimated size 10.9 MiB, free 421.5 MiB)
# 23/07/10 12:13:14 INFO BlockManagerInfo: Added rdd_525_0 in memory on 10.0.2.15:46735 (size: 10.9 MiB, free: 423.2 MiB)
# 23/07/10 12:13:14 INFO Executor: Finished task 0.0 in stage 220.0 (TID 206). 3535 bytes result sent to driver
# 23/07/10 12:13:14 INFO TaskSetManager: Finished task 0.0 in stage 220.0 (TID 206) in 1625 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:14 INFO TaskSchedulerImpl: Removed TaskSet 220.0, whose tasks have all completed, from pool
# 23/07/10 12:13:14 INFO DAGScheduler: ResultStage 220 (treeAggregate at RDDLossFunction.scala:61) finished in 1.640 s
# 23/07/10 12:13:14 INFO DAGScheduler: Job 200 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:14 INFO TaskSchedulerImpl: Killing all running tasks in stage 220: Stage finished
# 23/07/10 12:13:14 INFO DAGScheduler: Job 200 finished: treeAggregate at RDDLossFunction.scala:61, took 1.643329 s
# 23/07/10 12:13:14 INFO TorrentBroadcast: Destroying Broadcast(418) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:14 INFO BlockManagerInfo: Removed broadcast_418_piece0 on 10.0.2.15:46735 in memory (size: 260.0 B, free: 423.2 MiB)
# 23/07/10 12:13:14 INFO MemoryStore: Block broadcast_420 stored as values in memory (estimated size 504.0 B, free 421.5 MiB)
# 23/07/10 12:13:14 INFO MemoryStore: Block broadcast_420_piece0 stored as bytes in memory (estimated size 427.0 B, free 421.5 MiB)
# 23/07/10 12:13:14 INFO BlockManagerInfo: Added broadcast_420_piece0 in memory on 10.0.2.15:46735 (size: 427.0 B, free: 423.2 MiB)
# 23/07/10 12:13:14 INFO SparkContext: Created broadcast 420 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:15 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:15 INFO DAGScheduler: Got job 201 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:15 INFO DAGScheduler: Final stage: ResultStage 221 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:15 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:15 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:15 INFO DAGScheduler: Submitting ResultStage 221 (MapPartitionsRDD[527] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_421 stored as values in memory (estimated size 83.8 KiB, free 421.5 MiB)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_421_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 421.4 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Added broadcast_421_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 423.2 MiB)
# 23/07/10 12:13:15 INFO SparkContext: Created broadcast 421 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:15 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 221 (MapPartitionsRDD[527] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Adding task set 221.0 with 1 tasks resource profile 0
# 23/07/10 12:13:15 INFO TaskSetManager: Starting task 0.0 in stage 221.0 (TID 207) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:15 INFO Executor: Running task 0.0 in stage 221.0 (TID 207)
# 23/07/10 12:13:15 INFO BlockManager: Found block rdd_525_0 locally
# 23/07/10 12:13:15 INFO Executor: Finished task 0.0 in stage 221.0 (TID 207). 3449 bytes result sent to driver
# 23/07/10 12:13:15 INFO TaskSetManager: Finished task 0.0 in stage 221.0 (TID 207) in 187 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Removed TaskSet 221.0, whose tasks have all completed, from pool
# 23/07/10 12:13:15 INFO DAGScheduler: ResultStage 221 (treeAggregate at RDDLossFunction.scala:61) finished in 0.191 s
# 23/07/10 12:13:15 INFO DAGScheduler: Job 201 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Killing all running tasks in stage 221: Stage finished
# 23/07/10 12:13:15 INFO DAGScheduler: Job 201 finished: treeAggregate at RDDLossFunction.scala:61, took 0.196421 s
# 23/07/10 12:13:15 INFO TorrentBroadcast: Destroying Broadcast(420) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_422 stored as values in memory (estimated size 504.0 B, free 421.4 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Removed broadcast_420_piece0 on 10.0.2.15:46735 in memory (size: 427.0 B, free: 423.2 MiB)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_422_piece0 stored as bytes in memory (estimated size 427.0 B, free 421.4 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Added broadcast_422_piece0 in memory on 10.0.2.15:46735 (size: 427.0 B, free: 423.2 MiB)
# 23/07/10 12:13:15 INFO SparkContext: Created broadcast 422 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:15 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:15 INFO DAGScheduler: Got job 202 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:15 INFO DAGScheduler: Final stage: ResultStage 222 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:15 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:15 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:15 INFO DAGScheduler: Submitting ResultStage 222 (MapPartitionsRDD[528] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_423 stored as values in memory (estimated size 83.8 KiB, free 421.3 MiB)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_423_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 421.3 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Added broadcast_423_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 423.1 MiB)
# 23/07/10 12:13:15 INFO SparkContext: Created broadcast 423 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:15 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 222 (MapPartitionsRDD[528] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Adding task set 222.0 with 1 tasks resource profile 0
# 23/07/10 12:13:15 INFO TaskSetManager: Starting task 0.0 in stage 222.0 (TID 208) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:15 INFO Executor: Running task 0.0 in stage 222.0 (TID 208)
# 23/07/10 12:13:15 INFO BlockManager: Found block rdd_525_0 locally
# 23/07/10 12:13:15 INFO Executor: Finished task 0.0 in stage 222.0 (TID 208). 3449 bytes result sent to driver
# 23/07/10 12:13:15 INFO TaskSetManager: Finished task 0.0 in stage 222.0 (TID 208) in 137 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Removed TaskSet 222.0, whose tasks have all completed, from pool
# 23/07/10 12:13:15 INFO DAGScheduler: ResultStage 222 (treeAggregate at RDDLossFunction.scala:61) finished in 0.143 s
# 23/07/10 12:13:15 INFO DAGScheduler: Job 202 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Killing all running tasks in stage 222: Stage finished
# 23/07/10 12:13:15 INFO DAGScheduler: Job 202 finished: treeAggregate at RDDLossFunction.scala:61, took 0.160275 s
# 23/07/10 12:13:15 INFO TorrentBroadcast: Destroying Broadcast(422) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_424 stored as values in memory (estimated size 504.0 B, free 421.3 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Removed broadcast_422_piece0 on 10.0.2.15:46735 in memory (size: 427.0 B, free: 423.1 MiB)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_424_piece0 stored as bytes in memory (estimated size 427.0 B, free 421.3 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Added broadcast_424_piece0 in memory on 10.0.2.15:46735 (size: 427.0 B, free: 423.1 MiB)
# 23/07/10 12:13:15 INFO SparkContext: Created broadcast 424 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:15 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:15 INFO DAGScheduler: Got job 203 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:15 INFO DAGScheduler: Final stage: ResultStage 223 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:15 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:15 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:15 INFO DAGScheduler: Submitting ResultStage 223 (MapPartitionsRDD[529] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_425 stored as values in memory (estimated size 83.8 KiB, free 421.2 MiB)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_425_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 421.2 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Added broadcast_425_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 423.1 MiB)
# 23/07/10 12:13:15 INFO SparkContext: Created broadcast 425 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:15 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 223 (MapPartitionsRDD[529] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Adding task set 223.0 with 1 tasks resource profile 0
# 23/07/10 12:13:15 INFO TaskSetManager: Starting task 0.0 in stage 223.0 (TID 209) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:15 INFO Executor: Running task 0.0 in stage 223.0 (TID 209)
# 23/07/10 12:13:15 INFO BlockManager: Found block rdd_525_0 locally
# 23/07/10 12:13:15 INFO Executor: Finished task 0.0 in stage 223.0 (TID 209). 3449 bytes result sent to driver
# 23/07/10 12:13:15 INFO TaskSetManager: Finished task 0.0 in stage 223.0 (TID 209) in 209 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Removed TaskSet 223.0, whose tasks have all completed, from pool
# 23/07/10 12:13:15 INFO DAGScheduler: ResultStage 223 (treeAggregate at RDDLossFunction.scala:61) finished in 0.214 s
# 23/07/10 12:13:15 INFO DAGScheduler: Job 203 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Killing all running tasks in stage 223: Stage finished
# 23/07/10 12:13:15 INFO DAGScheduler: Job 203 finished: treeAggregate at RDDLossFunction.scala:61, took 0.216132 s
# 23/07/10 12:13:15 INFO TorrentBroadcast: Destroying Broadcast(424) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_426 stored as values in memory (estimated size 504.0 B, free 421.2 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Removed broadcast_424_piece0 on 10.0.2.15:46735 in memory (size: 427.0 B, free: 423.1 MiB)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_426_piece0 stored as bytes in memory (estimated size 427.0 B, free 421.2 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Added broadcast_426_piece0 in memory on 10.0.2.15:46735 (size: 427.0 B, free: 423.1 MiB)
# 23/07/10 12:13:15 INFO SparkContext: Created broadcast 426 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:15 INFO BlockManagerInfo: Removed broadcast_419_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 423.1 MiB)
# 23/07/10 12:13:15 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:15 INFO DAGScheduler: Got job 204 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:15 INFO DAGScheduler: Final stage: ResultStage 224 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:15 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:15 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:15 INFO DAGScheduler: Submitting ResultStage 224 (MapPartitionsRDD[530] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_427 stored as values in memory (estimated size 83.8 KiB, free 421.2 MiB)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_427_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 421.2 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Added broadcast_427_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 423.1 MiB)
# 23/07/10 12:13:15 INFO SparkContext: Created broadcast 427 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:15 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 224 (MapPartitionsRDD[530] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Adding task set 224.0 with 1 tasks resource profile 0
# 23/07/10 12:13:15 INFO TaskSetManager: Starting task 0.0 in stage 224.0 (TID 210) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:15 INFO Executor: Running task 0.0 in stage 224.0 (TID 210)
# 23/07/10 12:13:15 INFO BlockManager: Found block rdd_525_0 locally
# 23/07/10 12:13:15 INFO BlockManagerInfo: Removed broadcast_423_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 423.1 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Removed broadcast_421_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 423.2 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Removed broadcast_425_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 423.2 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Removed broadcast_176_piece0 on 10.0.2.15:46735 in memory (size: 35.1 KiB, free: 423.2 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Removed broadcast_105_piece0 on 10.0.2.15:46735 in memory (size: 35.1 KiB, free: 423.3 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Removed broadcast_273_piece0 on 10.0.2.15:46735 in memory (size: 35.1 KiB, free: 423.3 MiB)
# 23/07/10 12:13:15 INFO Executor: Finished task 0.0 in stage 224.0 (TID 210). 3449 bytes result sent to driver
# 23/07/10 12:13:15 INFO TaskSetManager: Finished task 0.0 in stage 224.0 (TID 210) in 239 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Removed TaskSet 224.0, whose tasks have all completed, from pool
# 23/07/10 12:13:15 INFO DAGScheduler: ResultStage 224 (treeAggregate at RDDLossFunction.scala:61) finished in 0.247 s
# 23/07/10 12:13:15 INFO DAGScheduler: Job 204 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Killing all running tasks in stage 224: Stage finished
# 23/07/10 12:13:15 INFO DAGScheduler: Job 204 finished: treeAggregate at RDDLossFunction.scala:61, took 0.249094 s
# 23/07/10 12:13:15 INFO TorrentBroadcast: Destroying Broadcast(426) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:15 INFO OWLQN: Step Size: 0.6222
# 23/07/10 12:13:15 INFO OWLQN: Val and Grad Norm: 2.42271 (rel: 0.0142) 0.209081
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_428 stored as values in memory (estimated size 504.0 B, free 422.2 MiB)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_428_piece0 stored as bytes in memory (estimated size 427.0 B, free 422.2 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Added broadcast_428_piece0 in memory on 10.0.2.15:46735 (size: 427.0 B, free: 423.3 MiB)
# 23/07/10 12:13:15 INFO SparkContext: Created broadcast 428 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:15 INFO BlockManagerInfo: Removed broadcast_426_piece0 on 10.0.2.15:46735 in memory (size: 427.0 B, free: 423.3 MiB)
# 23/07/10 12:13:15 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:15 INFO DAGScheduler: Got job 205 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:15 INFO DAGScheduler: Final stage: ResultStage 225 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:15 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:15 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:15 INFO DAGScheduler: Submitting ResultStage 225 (MapPartitionsRDD[531] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_429 stored as values in memory (estimated size 83.8 KiB, free 422.2 MiB)
# 23/07/10 12:13:15 INFO MemoryStore: Block broadcast_429_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 422.1 MiB)
# 23/07/10 12:13:15 INFO BlockManagerInfo: Added broadcast_429_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 423.3 MiB)
# 23/07/10 12:13:15 INFO SparkContext: Created broadcast 429 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:15 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 225 (MapPartitionsRDD[531] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:15 INFO TaskSchedulerImpl: Adding task set 225.0 with 1 tasks resource profile 0
# 23/07/10 12:13:15 INFO TaskSetManager: Starting task 0.0 in stage 225.0 (TID 211) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:15 INFO Executor: Running task 0.0 in stage 225.0 (TID 211)
# 23/07/10 12:13:15 INFO BlockManager: Found block rdd_525_0 locally
# 23/07/10 12:13:16 INFO Executor: Finished task 0.0 in stage 225.0 (TID 211). 3449 bytes result sent to driver
# 23/07/10 12:13:16 INFO TaskSetManager: Finished task 0.0 in stage 225.0 (TID 211) in 145 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:16 INFO TaskSchedulerImpl: Removed TaskSet 225.0, whose tasks have all completed, from pool
# 23/07/10 12:13:16 INFO DAGScheduler: ResultStage 225 (treeAggregate at RDDLossFunction.scala:61) finished in 0.151 s
# 23/07/10 12:13:16 INFO DAGScheduler: Job 205 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:16 INFO TaskSchedulerImpl: Killing all running tasks in stage 225: Stage finished
# 23/07/10 12:13:16 INFO DAGScheduler: Job 205 finished: treeAggregate at RDDLossFunction.scala:61, took 0.154098 s
# 23/07/10 12:13:16 INFO TorrentBroadcast: Destroying Broadcast(428) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:16 INFO OWLQN: Step Size: 1.000
# 23/07/10 12:13:16 INFO OWLQN: Val and Grad Norm: 2.31484 (rel: 0.0445) 0.0527008
# 23/07/10 12:13:16 INFO MemoryStore: Block broadcast_430 stored as values in memory (estimated size 504.0 B, free 422.1 MiB)
# 23/07/10 12:13:16 INFO MemoryStore: Block broadcast_430_piece0 stored as bytes in memory (estimated size 418.0 B, free 422.1 MiB)
# 23/07/10 12:13:16 INFO BlockManagerInfo: Added broadcast_430_piece0 in memory on 10.0.2.15:46735 (size: 418.0 B, free: 423.3 MiB)
# 23/07/10 12:13:16 INFO SparkContext: Created broadcast 430 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:16 INFO BlockManagerInfo: Removed broadcast_428_piece0 on 10.0.2.15:46735 in memory (size: 427.0 B, free: 423.3 MiB)
# 23/07/10 12:13:16 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:16 INFO DAGScheduler: Got job 206 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:16 INFO DAGScheduler: Final stage: ResultStage 226 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:16 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:16 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:16 INFO DAGScheduler: Submitting ResultStage 226 (MapPartitionsRDD[532] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:16 INFO MemoryStore: Block broadcast_431 stored as values in memory (estimated size 83.8 KiB, free 422.0 MiB)
# 23/07/10 12:13:16 INFO MemoryStore: Block broadcast_431_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 422.0 MiB)
# 23/07/10 12:13:16 INFO BlockManagerInfo: Added broadcast_431_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 423.2 MiB)
# 23/07/10 12:13:16 INFO SparkContext: Created broadcast 431 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:16 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 226 (MapPartitionsRDD[532] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:16 INFO TaskSchedulerImpl: Adding task set 226.0 with 1 tasks resource profile 0
# 23/07/10 12:13:16 INFO TaskSetManager: Starting task 0.0 in stage 226.0 (TID 212) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:16 INFO Executor: Running task 0.0 in stage 226.0 (TID 212)
# 23/07/10 12:13:16 INFO BlockManager: Found block rdd_525_0 locally
# 23/07/10 12:13:16 INFO Executor: Finished task 0.0 in stage 226.0 (TID 212). 3449 bytes result sent to driver
# 23/07/10 12:13:16 INFO TaskSetManager: Finished task 0.0 in stage 226.0 (TID 212) in 140 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:16 INFO TaskSchedulerImpl: Removed TaskSet 226.0, whose tasks have all completed, from pool
# 23/07/10 12:13:16 INFO DAGScheduler: ResultStage 226 (treeAggregate at RDDLossFunction.scala:61) finished in 0.150 s
# 23/07/10 12:13:16 INFO DAGScheduler: Job 206 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:16 INFO TaskSchedulerImpl: Killing all running tasks in stage 226: Stage finished
# 23/07/10 12:13:16 INFO DAGScheduler: Job 206 finished: treeAggregate at RDDLossFunction.scala:61, took 0.152266 s
# 23/07/10 12:13:16 INFO TorrentBroadcast: Destroying Broadcast(430) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:16 INFO OWLQN: Step Size: 1.000
# 23/07/10 12:13:16 INFO OWLQN: Val and Grad Norm: 2.30627 (rel: 0.00370) 0.0248128
# 23/07/10 12:13:16 INFO MemoryStore: Block broadcast_432 stored as values in memory (estimated size 504.0 B, free 422.0 MiB)
# 23/07/10 12:13:16 INFO BlockManagerInfo: Removed broadcast_430_piece0 on 10.0.2.15:46735 in memory (size: 418.0 B, free: 423.2 MiB)
# 23/07/10 12:13:16 INFO MemoryStore: Block broadcast_432_piece0 stored as bytes in memory (estimated size 403.0 B, free 422.0 MiB)
# 23/07/10 12:13:16 INFO BlockManagerInfo: Added broadcast_432_piece0 in memory on 10.0.2.15:46735 (size: 403.0 B, free: 423.2 MiB)
# 23/07/10 12:13:16 INFO SparkContext: Created broadcast 432 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:16 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:16 INFO DAGScheduler: Got job 207 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:16 INFO DAGScheduler: Final stage: ResultStage 227 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:16 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:16 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:16 INFO DAGScheduler: Submitting ResultStage 227 (MapPartitionsRDD[533] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:16 INFO MemoryStore: Block broadcast_433 stored as values in memory (estimated size 83.8 KiB, free 421.9 MiB)
# 23/07/10 12:13:16 INFO MemoryStore: Block broadcast_433_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 421.9 MiB)
# 23/07/10 12:13:16 INFO BlockManagerInfo: Added broadcast_433_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 423.2 MiB)
# 23/07/10 12:13:16 INFO SparkContext: Created broadcast 433 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:16 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 227 (MapPartitionsRDD[533] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:16 INFO TaskSchedulerImpl: Adding task set 227.0 with 1 tasks resource profile 0
# 23/07/10 12:13:16 INFO TaskSetManager: Starting task 0.0 in stage 227.0 (TID 213) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:16 INFO Executor: Running task 0.0 in stage 227.0 (TID 213)
# 23/07/10 12:13:16 INFO BlockManager: Found block rdd_525_0 locally
# 23/07/10 12:13:16 INFO BlockManagerInfo: Removed broadcast_429_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 423.2 MiB)
# 23/07/10 12:13:16 INFO BlockManagerInfo: Removed broadcast_427_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 423.3 MiB)
# 23/07/10 12:13:16 INFO BlockManagerInfo: Removed broadcast_431_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 423.3 MiB)
# 23/07/10 12:13:16 INFO Executor: Finished task 0.0 in stage 227.0 (TID 213). 3492 bytes result sent to driver
# 23/07/10 12:13:16 INFO TaskSetManager: Finished task 0.0 in stage 227.0 (TID 213) in 394 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:16 INFO TaskSchedulerImpl: Removed TaskSet 227.0, whose tasks have all completed, from pool
# 23/07/10 12:13:16 INFO DAGScheduler: ResultStage 227 (treeAggregate at RDDLossFunction.scala:61) finished in 0.401 s
# 23/07/10 12:13:16 INFO DAGScheduler: Job 207 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:16 INFO TaskSchedulerImpl: Killing all running tasks in stage 227: Stage finished
# 23/07/10 12:13:16 INFO DAGScheduler: Job 207 finished: treeAggregate at RDDLossFunction.scala:61, took 0.403201 s
# 23/07/10 12:13:16 INFO TorrentBroadcast: Destroying Broadcast(432) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:16 INFO OWLQN: Step Size: 1.000
# 23/07/10 12:13:16 INFO OWLQN: Val and Grad Norm: 2.30674 (rel: -0.000205) 0.0135324
# 23/07/10 12:13:16 INFO MemoryStore: Block broadcast_434 stored as values in memory (estimated size 504.0 B, free 422.2 MiB)
# 23/07/10 12:13:16 INFO MemoryStore: Block broadcast_434_piece0 stored as bytes in memory (estimated size 413.0 B, free 422.2 MiB)
# 23/07/10 12:13:16 INFO BlockManagerInfo: Added broadcast_434_piece0 in memory on 10.0.2.15:46735 (size: 413.0 B, free: 423.3 MiB)
# 23/07/10 12:13:16 INFO SparkContext: Created broadcast 434 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:16 INFO BlockManagerInfo: Removed broadcast_432_piece0 on 10.0.2.15:46735 in memory (size: 403.0 B, free: 423.3 MiB)
# 23/07/10 12:13:16 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:16 INFO DAGScheduler: Got job 208 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# ...
# 23/07/10 12:13:19 INFO DAGScheduler: Job 218 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:19 INFO TaskSchedulerImpl: Killing all running tasks in stage 238: Stage finished
# 23/07/10 12:13:19 INFO DAGScheduler: Job 218 finished: treeAggregate at RDDLossFunction.scala:61, took 0.138989 s
# 23/07/10 12:13:19 INFO TorrentBroadcast: Destroying Broadcast(454) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:19 INFO OWLQN: Step Size: 1.000
# 23/07/10 12:13:19 INFO BlockManagerInfo: Removed broadcast_454_piece0 on 10.0.2.15:46735 in memory (size: 416.0 B, free: 423.3 MiB)
# 23/07/10 12:13:19 INFO OWLQN: Val and Grad Norm: 2.30200 (rel: 1.38e-09) 9.14341e-06
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_456 stored as values in memory (estimated size 504.0 B, free 422.1 MiB)
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_456_piece0 stored as bytes in memory (estimated size 415.0 B, free 422.1 MiB)
# 23/07/10 12:13:19 INFO BlockManagerInfo: Added broadcast_456_piece0 in memory on 10.0.2.15:46735 (size: 415.0 B, free: 423.3 MiB)
# 23/07/10 12:13:19 INFO SparkContext: Created broadcast 456 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:19 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:19 INFO DAGScheduler: Got job 219 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:19 INFO DAGScheduler: Final stage: ResultStage 239 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:19 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:19 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:19 INFO DAGScheduler: Submitting ResultStage 239 (MapPartitionsRDD[545] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_457 stored as values in memory (estimated size 83.8 KiB, free 422.0 MiB)
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_457_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 422.0 MiB)
# 23/07/10 12:13:19 INFO BlockManagerInfo: Added broadcast_457_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 423.2 MiB)
# 23/07/10 12:13:19 INFO SparkContext: Created broadcast 457 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:19 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 239 (MapPartitionsRDD[545] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:19 INFO TaskSchedulerImpl: Adding task set 239.0 with 1 tasks resource profile 0
# 23/07/10 12:13:19 INFO TaskSetManager: Starting task 0.0 in stage 239.0 (TID 225) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:19 INFO Executor: Running task 0.0 in stage 239.0 (TID 225)
# 23/07/10 12:13:19 INFO BlockManager: Found block rdd_525_0 locally
# 23/07/10 12:13:19 INFO Executor: Finished task 0.0 in stage 239.0 (TID 225). 3492 bytes result sent to driver
# 23/07/10 12:13:19 INFO TaskSetManager: Finished task 0.0 in stage 239.0 (TID 225) in 229 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:19 INFO TaskSchedulerImpl: Removed TaskSet 239.0, whose tasks have all completed, from pool
# 23/07/10 12:13:19 INFO DAGScheduler: ResultStage 239 (treeAggregate at RDDLossFunction.scala:61) finished in 0.234 s
# 23/07/10 12:13:19 INFO DAGScheduler: Job 219 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:19 INFO TaskSchedulerImpl: Killing all running tasks in stage 239: Stage finished
# 23/07/10 12:13:19 INFO DAGScheduler: Job 219 finished: treeAggregate at RDDLossFunction.scala:61, took 0.236041 s
# 23/07/10 12:13:19 INFO TorrentBroadcast: Destroying Broadcast(456) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:19 INFO OWLQN: Step Size: 1.000
# 23/07/10 12:13:19 INFO BlockManagerInfo: Removed broadcast_456_piece0 on 10.0.2.15:46735 in memory (size: 415.0 B, free: 423.2 MiB)
# 23/07/10 12:13:19 INFO OWLQN: Val and Grad Norm: 2.30200 (rel: 2.35e-10) 5.46964e-06
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_458 stored as values in memory (estimated size 504.0 B, free 422.0 MiB)
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_458_piece0 stored as bytes in memory (estimated size 416.0 B, free 422.0 MiB)
# 23/07/10 12:13:19 INFO BlockManagerInfo: Added broadcast_458_piece0 in memory on 10.0.2.15:46735 (size: 416.0 B, free: 423.2 MiB)
# 23/07/10 12:13:19 INFO SparkContext: Created broadcast 458 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:19 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:19 INFO DAGScheduler: Got job 220 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:19 INFO DAGScheduler: Final stage: ResultStage 240 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:19 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:19 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:19 INFO DAGScheduler: Submitting ResultStage 240 (MapPartitionsRDD[546] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_459 stored as values in memory (estimated size 83.8 KiB, free 421.9 MiB)
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_459_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 421.9 MiB)
# 23/07/10 12:13:19 INFO BlockManagerInfo: Added broadcast_459_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 423.2 MiB)
# 23/07/10 12:13:19 INFO SparkContext: Created broadcast 459 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:19 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 240 (MapPartitionsRDD[546] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:19 INFO TaskSchedulerImpl: Adding task set 240.0 with 1 tasks resource profile 0
# 23/07/10 12:13:19 INFO TaskSetManager: Starting task 0.0 in stage 240.0 (TID 226) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:19 INFO Executor: Running task 0.0 in stage 240.0 (TID 226)
# 23/07/10 12:13:19 INFO BlockManager: Found block rdd_525_0 locally
# 23/07/10 12:13:19 INFO Executor: Finished task 0.0 in stage 240.0 (TID 226). 3449 bytes result sent to driver
# 23/07/10 12:13:19 INFO TaskSetManager: Finished task 0.0 in stage 240.0 (TID 226) in 159 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:19 INFO TaskSchedulerImpl: Removed TaskSet 240.0, whose tasks have all completed, from pool
# 23/07/10 12:13:19 INFO DAGScheduler: ResultStage 240 (treeAggregate at RDDLossFunction.scala:61) finished in 0.164 s
# 23/07/10 12:13:19 INFO DAGScheduler: Job 220 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:19 INFO TaskSchedulerImpl: Killing all running tasks in stage 240: Stage finished
# 23/07/10 12:13:19 INFO DAGScheduler: Job 220 finished: treeAggregate at RDDLossFunction.scala:61, took 0.169894 s
# 23/07/10 12:13:19 INFO TorrentBroadcast: Destroying Broadcast(458) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:19 INFO BlockManagerInfo: Removed broadcast_458_piece0 on 10.0.2.15:46735 in memory (size: 416.0 B, free: 423.2 MiB)
# 23/07/10 12:13:19 INFO OWLQN: Step Size: 1.000
# 23/07/10 12:13:19 INFO OWLQN: Val and Grad Norm: 2.30200 (rel: 1.65e-10) 3.25088e-06
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_460 stored as values in memory (estimated size 504.0 B, free 421.9 MiB)
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_460_piece0 stored as bytes in memory (estimated size 416.0 B, free 421.9 MiB)
# 23/07/10 12:13:19 INFO BlockManagerInfo: Added broadcast_460_piece0 in memory on 10.0.2.15:46735 (size: 416.0 B, free: 423.2 MiB)
# 23/07/10 12:13:19 INFO BlockManagerInfo: Removed broadcast_459_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 423.2 MiB)
# 23/07/10 12:13:19 INFO SparkContext: Created broadcast 460 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:19 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:19 INFO DAGScheduler: Got job 221 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:19 INFO DAGScheduler: Final stage: ResultStage 241 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:19 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:19 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:19 INFO DAGScheduler: Submitting ResultStage 241 (MapPartitionsRDD[547] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_461 stored as values in memory (estimated size 83.8 KiB, free 421.9 MiB)
# 23/07/10 12:13:19 INFO MemoryStore: Block broadcast_461_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 421.9 MiB)
# 23/07/10 12:13:19 INFO BlockManagerInfo: Added broadcast_461_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 423.2 MiB)
# 23/07/10 12:13:19 INFO SparkContext: Created broadcast 461 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:19 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 241 (MapPartitionsRDD[547] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:19 INFO TaskSchedulerImpl: Adding task set 241.0 with 1 tasks resource profile 0
# 23/07/10 12:13:19 INFO TaskSetManager: Starting task 0.0 in stage 241.0 (TID 227) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:19 INFO Executor: Running task 0.0 in stage 241.0 (TID 227)
# 23/07/10 12:13:19 INFO BlockManagerInfo: Removed broadcast_455_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 423.2 MiB)
# 23/07/10 12:13:19 INFO BlockManagerInfo: Removed broadcast_453_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 423.3 MiB)
# 23/07/10 12:13:19 INFO BlockManager: Found block rdd_525_0 locally
# 23/07/10 12:13:19 INFO BlockManagerInfo: Removed broadcast_457_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 423.3 MiB)
# 23/07/10 12:13:20 INFO Executor: Finished task 0.0 in stage 241.0 (TID 227). 3449 bytes result sent to driver
# 23/07/10 12:13:20 INFO TaskSetManager: Finished task 0.0 in stage 241.0 (TID 227) in 308 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:20 INFO TaskSchedulerImpl: Removed TaskSet 241.0, whose tasks have all completed, from pool
# 23/07/10 12:13:20 INFO DAGScheduler: ResultStage 241 (treeAggregate at RDDLossFunction.scala:61) finished in 0.314 s
# 23/07/10 12:13:20 INFO DAGScheduler: Job 221 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:20 INFO TaskSchedulerImpl: Killing all running tasks in stage 241: Stage finished
# 23/07/10 12:13:20 INFO DAGScheduler: Job 221 finished: treeAggregate at RDDLossFunction.scala:61, took 0.318113 s
# 23/07/10 12:13:20 INFO TorrentBroadcast: Destroying Broadcast(460) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:20 INFO MemoryStore: Block broadcast_462 stored as values in memory (estimated size 504.0 B, free 422.2 MiB)
# 23/07/10 12:13:20 INFO MemoryStore: Block broadcast_462_piece0 stored as bytes in memory (estimated size 416.0 B, free 422.2 MiB)
# 23/07/10 12:13:20 INFO BlockManagerInfo: Removed broadcast_460_piece0 on 10.0.2.15:46735 in memory (size: 416.0 B, free: 423.3 MiB)
# 23/07/10 12:13:20 INFO BlockManagerInfo: Added broadcast_462_piece0 in memory on 10.0.2.15:46735 (size: 416.0 B, free: 423.3 MiB)
# 23/07/10 12:13:20 INFO SparkContext: Created broadcast 462 from broadcast at RDDLossFunction.scala:57
# 23/07/10 12:13:20 INFO SparkContext: Starting job: treeAggregate at RDDLossFunction.scala:61
# 23/07/10 12:13:20 INFO DAGScheduler: Got job 222 (treeAggregate at RDDLossFunction.scala:61) with 1 output partitions
# 23/07/10 12:13:20 INFO DAGScheduler: Final stage: ResultStage 242 (treeAggregate at RDDLossFunction.scala:61)
# 23/07/10 12:13:20 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:20 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:20 INFO DAGScheduler: Submitting ResultStage 242 (MapPartitionsRDD[548] at treeAggregate at RDDLossFunction.scala:61), which has no missing parents
# 23/07/10 12:13:20 INFO MemoryStore: Block broadcast_463 stored as values in memory (estimated size 83.8 KiB, free 422.2 MiB)
# 23/07/10 12:13:20 INFO MemoryStore: Block broadcast_463_piece0 stored as bytes in memory (estimated size 33.4 KiB, free 422.1 MiB)
# 23/07/10 12:13:20 INFO BlockManagerInfo: Added broadcast_463_piece0 in memory on 10.0.2.15:46735 (size: 33.4 KiB, free: 423.3 MiB)
# 23/07/10 12:13:20 INFO SparkContext: Created broadcast 463 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:20 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 242 (MapPartitionsRDD[548] at treeAggregate at RDDLossFunction.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:20 INFO TaskSchedulerImpl: Adding task set 242.0 with 1 tasks resource profile 0
# 23/07/10 12:13:20 INFO TaskSetManager: Starting task 0.0 in stage 242.0 (TID 228) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:20 INFO Executor: Running task 0.0 in stage 242.0 (TID 228)
# 23/07/10 12:13:20 INFO BlockManager: Found block rdd_525_0 locally
# 23/07/10 12:13:20 INFO Executor: Finished task 0.0 in stage 242.0 (TID 228). 3449 bytes result sent to driver
# 23/07/10 12:13:20 INFO TaskSetManager: Finished task 0.0 in stage 242.0 (TID 228) in 167 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:20 INFO TaskSchedulerImpl: Removed TaskSet 242.0, whose tasks have all completed, from pool
# 23/07/10 12:13:20 INFO DAGScheduler: ResultStage 242 (treeAggregate at RDDLossFunction.scala:61) finished in 0.173 s
# 23/07/10 12:13:20 INFO DAGScheduler: Job 222 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:20 INFO TaskSchedulerImpl: Killing all running tasks in stage 242: Stage finished
# 23/07/10 12:13:20 INFO DAGScheduler: Job 222 finished: treeAggregate at RDDLossFunction.scala:61, took 0.175150 s
# 23/07/10 12:13:20 INFO TorrentBroadcast: Destroying Broadcast(462) (from destroy at RDDLossFunction.scala:68)
# 23/07/10 12:13:20 INFO OWLQN: Step Size: 0.5000
# 23/07/10 12:13:20 INFO OWLQN: Val and Grad Norm: 2.30200 (rel: 1.55e-11) 1.73995e-06
# 23/07/10 12:13:20 INFO OWLQN: Converged because gradient converged
# 23/07/10 12:13:20 INFO MapPartitionsRDD: Removing RDD 525 from persistence list
# 23/07/10 12:13:20 INFO BlockManagerInfo: Removed broadcast_462_piece0 on 10.0.2.15:46735 in memory (size: 416.0 B, free: 423.3 MiB)
# 23/07/10 12:13:20 INFO BlockManager: Removing RDD 525
# 23/07/10 12:13:20 INFO TorrentBroadcast: Destroying Broadcast(416) (from destroy at LogisticRegression.scala:1019)
# 23/07/10 12:13:20 INFO TorrentBroadcast: Destroying Broadcast(417) (from destroy at LogisticRegression.scala:1020)
# 23/07/10 12:13:20 INFO BlockManagerInfo: Removed broadcast_416_piece0 on 10.0.2.15:46735 in memory (size: 93.0 B, free: 434.2 MiB)
# 23/07/10 12:13:20 INFO BlockManagerInfo: Removed broadcast_417_piece0 on 10.0.2.15:46735 in memory (size: 93.0 B, free: 434.2 MiB)
# 23/07/10 12:13:20 INFO FileSourceStrategy: Pushed Filters:
# 23/07/10 12:13:20 INFO FileSourceStrategy: Post-Scan Filters:
# 23/07/10 12:13:20 INFO MemoryStore: Block broadcast_464 stored as values in memory (estimated size 201.8 KiB, free 432.8 MiB)
# 23/07/10 12:13:20 INFO MemoryStore: Block broadcast_464_piece0 stored as bytes in memory (estimated size 35.1 KiB, free 432.8 MiB)
# 23/07/10 12:13:20 INFO BlockManagerInfo: Added broadcast_464_piece0 in memory on 10.0.2.15:46735 (size: 35.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:20 INFO SparkContext: Created broadcast 464 from rdd at ClassificationSummary.scala:58
# 23/07/10 12:13:20 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.

# %%
prediction = model.transform(df_test)
df_test.show(5)
# Out:
# 23/07/10 12:13:20 INFO FileSourceStrategy: Pushed Filters:
# 23/07/10 12:13:20 INFO FileSourceStrategy: Post-Scan Filters:
# 23/07/10 12:13:20 INFO MemoryStore: Block broadcast_465 stored as values in memory (estimated size 201.8 KiB, free 432.6 MiB)
# 23/07/10 12:13:20 INFO MemoryStore: Block broadcast_465_piece0 stored as bytes in memory (estimated size 35.1 KiB, free 432.6 MiB)
# 23/07/10 12:13:20 INFO BlockManagerInfo: Added broadcast_465_piece0 in memory on 10.0.2.15:46735 (size: 35.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:20 INFO SparkContext: Created broadcast 465 from showString at NativeMethodAccessorImpl.java:0
# 23/07/10 12:13:20 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 23/07/10 12:13:20 INFO SparkContext: Starting job: showString at NativeMethodAccessorImpl.java:0
# 23/07/10 12:13:20 INFO DAGScheduler: Got job 223 (showString at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 23/07/10 12:13:20 INFO DAGScheduler: Final stage: ResultStage 243 (showString at NativeMethodAccessorImpl.java:0)
# 23/07/10 12:13:20 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:20 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:20 INFO DAGScheduler: Submitting ResultStage 243 (MapPartitionsRDD[559] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents
# 23/07/10 12:13:20 INFO MemoryStore: Block broadcast_466 stored as values in memory (estimated size 34.6 KiB, free 432.5 MiB)
# 23/07/10 12:13:20 INFO MemoryStore: Block broadcast_466_piece0 stored as bytes in memory (estimated size 14.5 KiB, free 432.5 MiB)
# 23/07/10 12:13:20 INFO BlockManagerInfo: Added broadcast_466_piece0 in memory on 10.0.2.15:46735 (size: 14.5 KiB, free: 434.1 MiB)
# 23/07/10 12:13:20 INFO SparkContext: Created broadcast 466 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:20 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 243 (MapPartitionsRDD[559] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:20 INFO TaskSchedulerImpl: Adding task set 243.0 with 1 tasks resource profile 0
# 23/07/10 12:13:20 INFO TaskSetManager: Starting task 0.0 in stage 243.0 (TID 229) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:20 INFO Executor: Running task 0.0 in stage 243.0 (TID 229)
# 23/07/10 12:13:20 INFO FileScanRDD: Reading File path: file:///home/davis/Private/main/data/data.parquet/part-00000-f0dd6904-04fe-4ee6-9a17-0c5e52be30ef-c000.snappy.parquet, range: 0-969453, partition values: [empty row]
# 23/07/10 12:13:20 INFO BlockManagerInfo: Removed broadcast_413_piece0 on 10.0.2.15:46735 in memory (size: 35.1 KiB, free: 434.1 MiB)
# 23/07/10 12:13:20 INFO BlockManagerInfo: Removed broadcast_463_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 434.1 MiB)
# 23/07/10 12:13:20 INFO BlockManagerInfo: Removed broadcast_461_piece0 on 10.0.2.15:46735 in memory (size: 33.4 KiB, free: 434.2 MiB)
# 23/07/10 12:13:20 INFO BlockManagerInfo: Removed broadcast_414_piece0 on 10.0.2.15:46735 in memory (size: 35.1 KiB, free: 434.2 MiB)
# 23/07/10 12:13:20 INFO BlockManager: Removing RDD 525
# +---+----+----+--------------------+--------------+
# |  x|   y|   z|              source|         class|
# +---+----+----+--------------------+--------------+
# |0.0|24.0|35.0|Accelerometer-201...| Sitdown_chair|
# |0.0|26.0|42.0|Accelerometer-201...|   Brush_teeth|
# |0.0|29.0|25.0|Accelerometer-201...|  Climb_stairs|
# |0.0|29.0|32.0|Accelerometer-201...|Descend_stairs|
# |0.0|29.0|46.0|Accelerometer-201...|   Brush_teeth|
# +---+----+----+--------------------+--------------+
# only showing top 5 rows
# 23/07/10 12:13:21 INFO Executor: Finished task 0.0 in stage 243.0 (TID 229). 2663 bytes result sent to driver
# 23/07/10 12:13:21 INFO TaskSetManager: Finished task 0.0 in stage 243.0 (TID 229) in 656 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:21 INFO TaskSchedulerImpl: Removed TaskSet 243.0, whose tasks have all completed, from pool
# 23/07/10 12:13:21 INFO DAGScheduler: ResultStage 243 (showString at NativeMethodAccessorImpl.java:0) finished in 0.660 s
# 23/07/10 12:13:21 INFO DAGScheduler: Job 223 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:21 INFO TaskSchedulerImpl: Killing all running tasks in stage 243: Stage finished
# 23/07/10 12:13:21 INFO DAGScheduler: Job 223 finished: showString at NativeMethodAccessorImpl.java:0, took 0.662525 s

# %%
prediction.show(5)
# Out:
# 23/07/10 12:13:21 INFO FileSourceStrategy: Pushed Filters:
# 23/07/10 12:13:21 INFO FileSourceStrategy: Post-Scan Filters:
# 23/07/10 12:13:21 INFO MemoryStore: Block broadcast_467 stored as values in memory (estimated size 201.8 KiB, free 433.0 MiB)
# 23/07/10 12:13:21 INFO MemoryStore: Block broadcast_467_piece0 stored as bytes in memory (estimated size 35.1 KiB, free 433.0 MiB)
# 23/07/10 12:13:21 INFO BlockManagerInfo: Added broadcast_467_piece0 in memory on 10.0.2.15:46735 (size: 35.1 KiB, free: 434.2 MiB)
# 23/07/10 12:13:21 INFO SparkContext: Created broadcast 467 from showString at NativeMethodAccessorImpl.java:0
# 23/07/10 12:13:21 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 23/07/10 12:13:21 INFO SparkContext: Starting job: showString at NativeMethodAccessorImpl.java:0
# 23/07/10 12:13:21 INFO DAGScheduler: Got job 224 (showString at NativeMethodAccessorImpl.java:0) with 1 output partitions
# 23/07/10 12:13:21 INFO DAGScheduler: Final stage: ResultStage 244 (showString at NativeMethodAccessorImpl.java:0)
# 23/07/10 12:13:21 INFO DAGScheduler: Parents of final stage: List()
# 23/07/10 12:13:21 INFO DAGScheduler: Missing parents: List()
# 23/07/10 12:13:21 INFO DAGScheduler: Submitting ResultStage 244 (MapPartitionsRDD[563] at showString at NativeMethodAccessorImpl.java:0), which has no missing parents
# 23/07/10 12:13:21 INFO MemoryStore: Block broadcast_468 stored as values in memory (estimated size 93.4 KiB, free 432.9 MiB)
# 23/07/10 12:13:21 INFO MemoryStore: Block broadcast_468_piece0 stored as bytes in memory (estimated size 33.5 KiB, free 432.8 MiB)
# 23/07/10 12:13:21 INFO BlockManagerInfo: Added broadcast_468_piece0 in memory on 10.0.2.15:46735 (size: 33.5 KiB, free: 434.1 MiB)
# 23/07/10 12:13:21 INFO SparkContext: Created broadcast 468 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:21 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 244 (MapPartitionsRDD[563] at showString at NativeMethodAccessorImpl.java:0) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:21 INFO TaskSchedulerImpl: Adding task set 244.0 with 1 tasks resource profile 0
# 23/07/10 12:13:21 INFO TaskSetManager: Starting task 0.0 in stage 244.0 (TID 230) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7997 bytes)
# 23/07/10 12:13:21 INFO Executor: Running task 0.0 in stage 244.0 (TID 230)
# 23/07/10 12:13:21 INFO FileScanRDD: Reading File path: file:///home/davis/Private/main/data/data.parquet/part-00000-f0dd6904-04fe-4ee6-9a17-0c5e52be30ef-c000.snappy.parquet, range: 0-969453, partition values: [empty row]
# 23/07/10 12:13:21 INFO BlockManagerInfo: Removed broadcast_466_piece0 on 10.0.2.15:46735 in memory (size: 14.5 KiB, free: 434.2 MiB)
# 23/07/10 12:13:21 INFO BlockManagerInfo: Removed broadcast_465_piece0 on 10.0.2.15:46735 in memory (size: 35.1 KiB, free: 434.2 MiB)
# [Stage 244:>                                                        (0 + 1) / 1]
# +---+----+----+--------------------+--------------+-----+---------------+--------------------+--------------------+--------------------+----------+
# |  x|   y|   z|              source|         class|label|       features|       features_norm|       rawPrediction|         probability|prediction|
# +---+----+----+--------------------+--------------+-----+---------------+--------------------+--------------------+--------------------+----------+
# |0.0|24.0|35.0|Accelerometer-201...| Sitdown_chair|  8.0|[0.0,24.0,35.0]|[0.0,0.3809523809...|[3.15713533103328...|[0.55706803819486...|       0.0|
# |0.0|26.0|42.0|Accelerometer-201...|   Brush_teeth|  6.0|[0.0,26.0,42.0]|[0.0,0.4126984126...|[2.87880414855864...|[0.48285900679348...|       0.0|
# |0.0|29.0|25.0|Accelerometer-201...|  Climb_stairs|  4.0|[0.0,29.0,25.0]|[0.0,0.4603174603...|[3.55475130599705...|[0.63946982831892...|       0.0|
# |0.0|29.0|32.0|Accelerometer-201...|Descend_stairs| 10.0|[0.0,29.0,32.0]|[0.0,0.4603174603...|[3.27642012352241...|[0.58222760721683...|       0.0|
# |0.0|29.0|46.0|Accelerometer-201...|   Brush_teeth|  6.0|[0.0,29.0,46.0]|[0.0,0.4603174603...|[2.71975775857313...|[0.43529380914198...|       0.0|
# +---+----+----+--------------------+--------------+-----+---------------+--------------------+--------------------+--------------------+----------+
# only showing top 5 rows
# 23/07/10 12:13:22 INFO Executor: Finished task 0.0 in stage 244.0 (TID 230). 5455 bytes result sent to driver
# 23/07/10 12:13:22 INFO TaskSetManager: Finished task 0.0 in stage 244.0 (TID 230) in 905 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:22 INFO TaskSchedulerImpl: Removed TaskSet 244.0, whose tasks have all completed, from pool
# 23/07/10 12:13:22 INFO DAGScheduler: ResultStage 244 (showString at NativeMethodAccessorImpl.java:0) finished in 0.910 s
# 23/07/10 12:13:22 INFO DAGScheduler: Job 224 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:22 INFO TaskSchedulerImpl: Killing all running tasks in stage 244: Stage finished
# 23/07/10 12:13:22 INFO DAGScheduler: Job 224 finished: showString at NativeMethodAccessorImpl.java:0, took 0.912765 s

# %%
binEval = MulticlassClassificationEvaluator(). \
    setMetricName("accuracy"). \
    setPredictionCol("prediction"). \
    setLabelCol("label")

binEval.evaluate(prediction)
# Out:
# 23/07/10 12:13:22 INFO FileSourceStrategy: Pushed Filters:
# 23/07/10 12:13:22 INFO FileSourceStrategy: Post-Scan Filters:
# 23/07/10 12:13:22 INFO MemoryStore: Block broadcast_469 stored as values in memory (estimated size 201.8 KiB, free 432.9 MiB)
# 23/07/10 12:13:22 INFO MemoryStore: Block broadcast_469_piece0 stored as bytes in memory (estimated size 35.1 KiB, free 432.9 MiB)
# 23/07/10 12:13:22 INFO BlockManagerInfo: Added broadcast_469_piece0 in memory on 10.0.2.15:46735 (size: 35.1 KiB, free: 434.2 MiB)
# 23/07/10 12:13:22 INFO SparkContext: Created broadcast 469 from rdd at MulticlassClassificationEvaluator.scala:191
# 23/07/10 12:13:22 INFO FileSourceScanExec: Planning scan with bin packing, max size: 4194304 bytes, open cost is considered as scanning 4194304 bytes.
# 23/07/10 12:13:22 INFO SparkContext: Starting job: collectAsMap at MulticlassMetrics.scala:61
# 23/07/10 12:13:22 INFO DAGScheduler: Registering RDD 571 (map at MulticlassMetrics.scala:52) as input to shuffle 20
# 23/07/10 12:13:22 INFO DAGScheduler: Got job 225 (collectAsMap at MulticlassMetrics.scala:61) with 1 output partitions
# 23/07/10 12:13:22 INFO DAGScheduler: Final stage: ResultStage 246 (collectAsMap at MulticlassMetrics.scala:61)
# 23/07/10 12:13:22 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 245)
# 23/07/10 12:13:22 INFO DAGScheduler: Missing parents: List(ShuffleMapStage 245)
# 23/07/10 12:13:22 INFO DAGScheduler: Submitting ShuffleMapStage 245 (MapPartitionsRDD[571] at map at MulticlassMetrics.scala:52), which has no missing parents
# 23/07/10 12:13:22 INFO MemoryStore: Block broadcast_470 stored as values in memory (estimated size 88.0 KiB, free 432.8 MiB)
# 23/07/10 12:13:22 INFO MemoryStore: Block broadcast_470_piece0 stored as bytes in memory (estimated size 34.5 KiB, free 432.8 MiB)
# 23/07/10 12:13:22 INFO BlockManagerInfo: Added broadcast_470_piece0 in memory on 10.0.2.15:46735 (size: 34.5 KiB, free: 434.1 MiB)
# 23/07/10 12:13:22 INFO SparkContext: Created broadcast 470 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:22 INFO DAGScheduler: Submitting 1 missing tasks from ShuffleMapStage 245 (MapPartitionsRDD[571] at map at MulticlassMetrics.scala:52) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:22 INFO TaskSchedulerImpl: Adding task set 245.0 with 1 tasks resource profile 0
# 23/07/10 12:13:22 INFO TaskSetManager: Starting task 0.0 in stage 245.0 (TID 231) (10.0.2.15, executor driver, partition 0, PROCESS_LOCAL, 7986 bytes)
# 23/07/10 12:13:22 INFO Executor: Running task 0.0 in stage 245.0 (TID 231)
# 23/07/10 12:13:22 INFO FileScanRDD: Reading File path: file:///home/davis/Private/main/data/data.parquet/part-00000-f0dd6904-04fe-4ee6-9a17-0c5e52be30ef-c000.snappy.parquet, range: 0-969453, partition values: [empty row]
# 23/07/10 12:13:22 INFO BlockManagerInfo: Removed broadcast_467_piece0 on 10.0.2.15:46735 in memory (size: 35.1 KiB, free: 434.2 MiB)
# 23/07/10 12:13:22 INFO BlockManagerInfo: Removed broadcast_468_piece0 on 10.0.2.15:46735 in memory (size: 33.5 KiB, free: 434.2 MiB)
# 23/07/10 12:13:23 INFO Executor: Finished task 0.0 in stage 245.0 (TID 231). 2344 bytes result sent to driver
# 23/07/10 12:13:23 INFO TaskSetManager: Finished task 0.0 in stage 245.0 (TID 231) in 1188 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:23 INFO TaskSchedulerImpl: Removed TaskSet 245.0, whose tasks have all completed, from pool
# 23/07/10 12:13:23 INFO DAGScheduler: ShuffleMapStage 245 (map at MulticlassMetrics.scala:52) finished in 1.203 s
# 23/07/10 12:13:23 INFO DAGScheduler: looking for newly runnable stages
# 23/07/10 12:13:23 INFO DAGScheduler: running: Set()
# 23/07/10 12:13:23 INFO DAGScheduler: waiting: Set(ResultStage 246)
# 23/07/10 12:13:23 INFO DAGScheduler: failed: Set()
# 23/07/10 12:13:23 INFO DAGScheduler: Submitting ResultStage 246 (ShuffledRDD[572] at reduceByKey at MulticlassMetrics.scala:61), which has no missing parents
# 23/07/10 12:13:23 INFO MemoryStore: Block broadcast_471 stored as values in memory (estimated size 4.7 KiB, free 433.1 MiB)
# 23/07/10 12:13:23 INFO MemoryStore: Block broadcast_471_piece0 stored as bytes in memory (estimated size 2.8 KiB, free 433.1 MiB)
# 23/07/10 12:13:23 INFO BlockManagerInfo: Added broadcast_471_piece0 in memory on 10.0.2.15:46735 (size: 2.8 KiB, free: 434.2 MiB)
# 23/07/10 12:13:23 INFO SparkContext: Created broadcast 471 from broadcast at DAGScheduler.scala:1535
# 23/07/10 12:13:23 INFO DAGScheduler: Submitting 1 missing tasks from ResultStage 246 (ShuffledRDD[572] at reduceByKey at MulticlassMetrics.scala:61) (first 15 tasks are for partitions Vector(0))
# 23/07/10 12:13:23 INFO TaskSchedulerImpl: Adding task set 246.0 with 1 tasks resource profile 0
# 23/07/10 12:13:23 INFO TaskSetManager: Starting task 0.0 in stage 246.0 (TID 232) (10.0.2.15, executor driver, partition 0, NODE_LOCAL, 7181 bytes)
# 23/07/10 12:13:23 INFO Executor: Running task 0.0 in stage 246.0 (TID 232)
# 23/07/10 12:13:23 INFO ShuffleBlockFetcherIterator: Getting 1 (1399.0 B) non-empty blocks including 1 (1399.0 B) local and 0 (0.0 B) host-local and 0 (0.0 B) push-merged-local and 0 (0.0 B) remote blocks
# 23/07/10 12:13:23 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 0 ms
# 23/07/10 12:13:23 INFO Executor: Finished task 0.0 in stage 246.0 (TID 232). 4896 bytes result sent to driver
# 23/07/10 12:13:23 INFO TaskSetManager: Finished task 0.0 in stage 246.0 (TID 232) in 9 ms on 10.0.2.15 (executor driver) (1/1)
# 23/07/10 12:13:23 INFO TaskSchedulerImpl: Removed TaskSet 246.0, whose tasks have all completed, from pool
# 23/07/10 12:13:23 INFO DAGScheduler: ResultStage 246 (collectAsMap at MulticlassMetrics.scala:61) finished in 0.012 s
# 23/07/10 12:13:23 INFO DAGScheduler: Job 225 is finished. Cancelling potential speculative or zombie tasks for this job
# 23/07/10 12:13:23 INFO TaskSchedulerImpl: Killing all running tasks in stage 246: Stage finished
# 23/07/10 12:13:23 INFO DAGScheduler: Job 225 finished: collectAsMap at MulticlassMetrics.scala:61, took 1.218169 s
# 0.3342259713016893
# 23/07/10 12:31:24 INFO BlockManagerInfo: Removed broadcast_470_piece0 on 10.0.2.15:46735 in memory (size: 34.5 KiB, free: 434.2 MiB)
# 23/07/10 12:31:24 INFO BlockManagerInfo: Removed broadcast_469_piece0 on 10.0.2.15:46735 in memory (size: 35.1 KiB, free: 434.3 MiB)
# 23/07/10 12:31:24 INFO BlockManagerInfo: Removed broadcast_471_piece0 on 10.0.2.15:46735 in memory (size: 2.8 KiB, free: 434.3 MiB)
# 23/07/10 12:39:51 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 294184 ms exceeds timeout 120000 ms
# 23/07/10 12:39:51 WARN SparkContext: Killing executors is not supported by current scheduler.
# 23/07/10 12:39:51 INFO Executor: Told to re-register on heartbeat
# 23/07/10 12:39:51 INFO BlockManager: BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None) re-registering with master
# 23/07/10 12:39:51 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None)
# 23/07/10 12:39:51 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@10.0.2.15:37877
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 23/07/10 12:39:51 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1111)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:244)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2088)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@10.0.2.15:37877
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 23/07/10 12:39:51 INFO Executor: Told to re-register on heartbeat
# 23/07/10 12:39:51 INFO BlockManager: BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None) re-registering with master
# 23/07/10 12:39:51 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None)
# 23/07/10 12:39:51 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@10.0.2.15:37877
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 23/07/10 12:39:51 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1111)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:244)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2088)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@10.0.2.15:37877
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 23/07/10 12:39:51 INFO Executor: Told to re-register on heartbeat
# 23/07/10 12:39:51 INFO BlockManager: BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None) re-registering with master
# 23/07/10 12:39:51 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None)
# 23/07/10 12:39:51 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@10.0.2.15:37877
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 23/07/10 12:39:51 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1111)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:244)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2088)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@10.0.2.15:37877
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 23/07/10 12:39:51 INFO Executor: Told to re-register on heartbeat
# 23/07/10 12:39:51 INFO BlockManager: BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None) re-registering with master
# 23/07/10 12:39:51 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None)
# 23/07/10 12:39:51 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@10.0.2.15:37877
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 23/07/10 12:39:51 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1111)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:244)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2088)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@10.0.2.15:37877
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 23/07/10 12:39:51 INFO Executor: Told to re-register on heartbeat
# 23/07/10 12:39:51 INFO BlockManager: BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None) re-registering with master
# 23/07/10 12:39:51 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None)
# 23/07/10 12:39:51 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# ...
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 23/07/10 12:42:07 INFO Executor: Told to re-register on heartbeat
# 23/07/10 12:42:07 INFO BlockManager: BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None) re-registering with master
# 23/07/10 12:42:07 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.2.15, 46735, None)
# 23/07/10 12:42:07 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@10.0.2.15:37877
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 23/07/10 12:42:07 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:641)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1111)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:244)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2088)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:322)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:117)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:116)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:611)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:610)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:648)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@10.0.2.15:37877
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more

# %%
pmmlBuilder = PMMLBuilder(sc, df_train, model)
pmmlBuilder.buildFile(data_dir + model_target)
